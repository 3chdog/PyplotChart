useAdam = [(0.06688967073642754, 9798), (0.08022836508535885, 9769), (0.08425274743592437, 9772), (0.05147648672867991, 9857), (0.09219806793711702, 9741), (0.07328434065212731, 9841), (0.0667027796889785, 9840), (0.06535147233702032, 9863), (0.08518876730688388, 9792), (0.0507975274879674, 9886), (0.051737071263244304, 9887), (0.05212612007302527, 9894), (0.051082756615386055, 9900), (0.05067768073664249, 9898), (0.0565340991383949, 9900), (0.05222649213432812, 9903), (0.05281888787474404, 9903), (0.05486918994155749, 9902), (0.057144319888755464, 9905), (0.05463131582121294, 9905), (0.091509884659531, 9713), (0.06404081267552285, 9805), (0.07258500194742898, 9802), (0.07419169086762527, 9809), (0.07121215397020496, 9825), (0.06338241429928737, 9815), (0.06937552217535581, 9823), (0.0891302975713971, 9810), (0.07465368470757658, 9845), (0.046996449519691494, 9894), (0.04634542937031866, 9890), (0.04835840434044499, 9895), (0.04744507057440859, 9896), (0.05192436701587281, 9894), (0.0513312027975431, 9897), (0.05151372976652516, 9899), (0.051639573913033456, 9898), (0.052044364610485935, 9899), (0.0524428001357868, 9899), (0.05391737314712833, 9899)]
useRSPprop = [(2.3081736504277095, 1009), (2.308638989170895, 982), (2.3115897148470337, 1032), (2.3107968674430364, 1010), (2.304011353963538, 1135), (2.305216046828258, 1135), (2.30586904513685, 1135), (2.3110284473322613, 974), (2.305657646324061, 1135), (2.3013221402711506, 1135), (2.3015793245049974, 1028), (2.3013615910011, 1135), (2.3012127121792565, 1135), (2.3016552442236793, 1135), (2.3011005588724642, 1135), (2.3010725009290476, 1135), (2.301246975041643, 1135), (2.300991849054264, 1135), (2.3010113178929195, 1135), (2.300814821750303, 1135), (2.3132163361658025, 958), (2.307595108128801, 958), (2.3064755065531672, 1028), (2.3065701858906804, 982), (2.3069186995301068, 1135), (2.305270077307013, 980), (2.3111747488190857, 1010), (2.303837021694908, 1135), (2.310232802282406, 958), (2.3018193607088886, 1135), (2.3015871923181077, 1135), (2.302726145032086, 1135), (2.3009911669960506, 1135), (2.301597761202462, 1135), (2.301047141038919, 1135), (2.3012706750555885, 1135), (2.3007864650291734, 1135), (2.3011566475976872, 1135), (2.3012911368019973, 1135), (2.3010202570806575, 1135)]

#將以上五種情況，先建立他們的index陣列，再將它們分成loss陣列與correct陣列
origin_range = range(len(origin))
origin_loss = []
origin_correct = []
for i in range(len(origin)):
    origin_loss.append(origin[i][0])
    origin_correct.append(origin[i][1])

add2Conv_range = range(len(add2Conv))
add2Conv_loss = []
add2Conv_correct = []
for i in range(len(add2Conv)):
    add2Conv_loss.append(add2Conv[i][0])
    add2Conv_correct.append(add2Conv[i][1])

addNeuron_range = range(len(addNeuron))
addNeuron_loss = []
addNeuron_correct = []
for i in range(len(addNeuron)):
    addNeuron_loss.append(addNeuron[i][0])
    addNeuron_correct.append(addNeuron[i][1])

useAdam_range = range(len(useAdam))
useAdam_loss = []
useAdam_correct = []
for i in range(len(useAdam)):
    useAdam_loss.append(useAdam[i][0])
    useAdam_correct.append(useAdam[i][1])

useRSPprop_range = range(len(useRSPprop))
useRSPprop_loss = []
useRSPprop_correct = []
for i in range(len(useRSPprop)):
    useRSPprop_loss.append(useRSPprop[i][0])
    useRSPprop_correct.append(useRSPprop[i][1])


#將五種情況的loss畫在同一個畫布上
line = plt.plot(origin_range, origin_loss, color = 'r',
               marker = 'o', label = 'origin')
line = plt.plot(add2Conv_range, add2Conv_loss, color = 'g',
               marker = 'o', label = 'add2Conv')
line = plt.plot(addNeuron_range, addNeuron_loss, color = 'b',
               marker = 'o', label = 'addNeuron')
line = plt.plot(useAdam_range, useAdam_loss, color = 'c',
               marker = 'o', label = 'useAdam')
line = plt.plot(useRSPprop_range, useRSPprop_loss, color = 'm',
               marker = 'o', label = 'useRSPprop')
plt.legend(loc = 'upper left')
plt.title('Loss')
plt.show()
'''
testing function的loss比較結論：
「增加神經元 addNeuron」與「使用最佳化器Adam useAdam」出來的loss曲線
比較像原版的(不做調整的)曲線，都是一開始loss值在0.06~0.09左右，最後落在0.025~0.05左右
其中又以「增加神經元 addNeuron」更接近原版，「使用最佳化器Adam useAdam」較差

而「增加兩個Conv add2Conv」，雖然以結論來看，loss值有回到原版的值：0.05左右
但是看曲線會發現，在第20、21筆數據那邊，有奇怪的凸出
在「增加兩個Conv add2Conv」的py檔，我增加了兩個convolution：conv1a與conv1b
沒有增加最後的Neuron，但將所有的convolution的kernal與pool的kernal都改成2x2
目前不清楚是否跟這些有關係。
（有嘗試過將kernal改成3x3，但是程式無法運行，會顯示tensor長寬不合，無法運算，因此全部改成2x2）

最後，「使用最佳化器RSP prop useRSPprop」中，發現所有的loss值都是非常高
在這個py檔中，我只有將最佳化器從SGD改成RSPprop，其他參數沒有調整
因此，我認為，最佳化器RSPprop不適合用在NMIST這類型的問題
'''

#將五種情況的correct畫在同一個畫布上
line = plt.plot(origin_range, origin_correct, color = 'r',
               marker = 'o', label = 'origin')
line = plt.plot(add2Conv_range, add2Conv_correct, color = 'g',
               marker = 'o', label = 'add2Conv')
line = plt.plot(addNeuron_range, addNeuron_correct, color = 'b',
               marker = 'o', label = 'addNeuron')
line = plt.plot(useAdam_range, useAdam_correct, color = 'c',
               marker = 'o', label = 'useAdam')
line = plt.plot(useRSPprop_range, useRSPprop_correct, color = 'm',
               marker = 'o', label = 'useRSPprop')
plt.legend(loc = 'upper left')
plt.title('Correct')
plt.show()
'''
testing function的correct比較結論：
這邊結論與上面的loss值比較結論相似。

「增加神經元 addNeuron」與「使用最佳化器Adam useAdam」出來的correct曲線
與原版的曲線相近，correct值最後落在9900±20左右。

「增加兩個Conv add2Conv」，以結論來看，Correct值有回到接近原版的值：9810左右
但是看曲線會發現，在第20、21筆數據那邊，有奇怪的凹下，與上面猜測相同

最後，「使用最佳化器RSP prop useRSPprop」中，一樣是蠻糟的成果，
Correct值一直很低，介在1000~1130
'''
